# %% [markdown]
# <a href="https://colab.research.google.com/github/Odigie43/computer-vision-on-image-processing/blob/main/display_%26_resize_image_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2

# Your code goes here

# %%
from IPython.core.display import Image
Image= cv2.imread('/content/drive/MyDrive/dogs/images (1).jpg', cv2.IMREAD_COLOR)
print("Shape of the loaded image is", Image.shape)
# Out:
# Shape of the loaded image is (168, 300, 3)

# %% [markdown]
# ## Task 2 - Display the image
# To display the image, you need to:
# > ✅ Use `cv2_imshow()` function. You can see we have already `import` the function for you

# %%
from google.colab.patches import cv2_imshow

# Your code goes here
cv2_imshow(Image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F36B4695E20>

# %%
from google.colab.patches import cv2_imshow


cv2_imshow(Image)  # Pay special attention to "_" (underscore)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F3681550580>

# %%
# Start coordinate, here (5, 5)
Image=cv2.imread('/content/drive/MyDrive/dogs/images (1).jpg')
start_point = (20, 20)
end_point = (220, 220)
color = (255, 0, 0)
thickness = 2
image = cv2.rectangle(Image, start_point, end_point, color, thickness)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F36814C28B0>

# %%
Image=cv2.imread('/content/drive/MyDrive/dogs/images (1).jpg')
start_point = (100, 50)
end_point = (125, 80)
color = (0, 0, 0)
thickness = -1
image = cv2.rectangle(Image, start_point, end_point, color, thickness)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F36814F6520>

# %%
# font to put text in ur image
font = cv2.FONT_HERSHEY_SIMPLEX

org = (50, 50)

# fontScale
fontScale = 1

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.putText() method
image = cv2.putText(Image, '', org, font,
                   fontScale, color, thickness, cv2.LINE_AA)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F3681550A00>

# %%
center_coordinates = (120, 100)

axesLength = (100, 50)

angle = 0

startAngle = 0

endAngle = 360

color = (0, 0, 255)

thickness = 5

# Using cv2.ellipse() method
# Draw a ellipse with red line borders of thickness of 5 px
image = cv2.ellipse(Image, center_coordinates, axesLength,
           angle, startAngle, endAngle, color, thickness)

cv2_imshow(Image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F368148D130>

# %%
center_coordinates = (120, 100)

axesLength = (100, 50)

angle = 30

startAngle = 0

endAngle = 360

color = (255, 0, 0)

thickness = -1

image = cv2.ellipse(image, center_coordinates, axesLength, angle,
                          startAngle, endAngle, color, thickness)

cv2_imshow(Image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F36814F6F70>

# %%
# ksize
ksize = (20, 30)
image = cv2.blur(Image, ksize, cv2.BORDER_DEFAULT)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F368150E0A0>

# %%
# ksize
ksize = (10, 10)
image = cv2.blur(Image, ksize)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F36814F6220>

# %% [markdown]
# To display the array of the image

# %%
Image
# Out:
# array([[[217, 217, 217],
#         [217, 217, 217],
#         [218, 218, 218],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [218, 218, 218],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[217, 217, 217],
#         [218, 218, 218],
#         [218, 218, 218],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        ...,
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
# ...

# %%
# Your code goes here
blue_image=Image[:,:,2]
new_image=blue_image[20,20]
new_image
# Out:
# 226

# %% [markdown]
# ## Task 5 - Resize the image
#
# > ✅ Check this [doc](https://docs.opencv.org/4.x/da/d54/group__imgproc__transform.html#ga47a974309e9102f5f08231edc7e7529d) and learn how to use `cv2.resize()` function.

# %%
#to resize the image,to increase the image
img_array = cv2.resize(Image, dsize=(299, 299), interpolation=cv2.INTER_CUBIC)
cv2_imshow(img_array)
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F3679046D60>

# %%
img_array = cv2.resize(Image, dsize=(100, 100), interpolation=cv2.INTER_CUBIC)
cv2_imshow(img_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F367913DFA0>

# %% [markdown]
# ## Task 6 - Draw shapes and texts (Overlay) on the image
#
# Check [this example](https://docs.opencv.org/4.x/dc/da5/tutorial_py_drawing_functions.html) and draw an blue rectangle over your original image
